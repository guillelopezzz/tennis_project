# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importar el data set
dataset = pd.read_csv('match_stats_extended_2022.csv')
torneos = pd.read_csv('tournaments_2020-2022.csv')

# %%
print(torneos)
# Out:
#      2020-8888   1          ATP Cup                            ATP Cup.1  \
# 0     2020-451   2          ATP 250                                 Doha
# 1    2020-8998   3          ATP 250                             Adelaide
# 2     2020-301   4          ATP 250                             Auckland
# 3     2020-580   5       Grand Slam                      Australian Open
# 4    2020-9158   6          ATP 250                              Cordoba
# ..         ...  ..              ...                                  ...
# 216   2022-337  67          ATP 500                      Erste Bank Open
# 217   2022-328  68          ATP 500                  Swiss Indoors Basel
# 218   2022-352  69     Masters 1000                  Rolex Paris Masters
# 219  2022-7696  70  Next Gen Finals  Intesa Sanpaolo Next Gen ATP Finals
# 220   2022-605  71       ATP Finals                     Nitto ATP Finals
#
#      8888                              atp-cup  \
# ...

# %%
X = dataset.iloc[:, [3, 14]].values
T_ind = torneos.iloc[:, [22]].values
T_dob_1 = torneos.iloc[:, [-5]].values
T_dob_2 = torneos.iloc[:, [-1]].values
T_dob = np.concatenate((T_dob_1, T_dob_2))

# %%
print(T_ind)
print(T_dob)
# Out:
# [['re44']
#  ['re44']
#  ['hh26']
#  ['d643']
#  ['gd64']
#  ['v708']
#  ['mc65']
#  ['mc65']
#  ['e831']
#  ['rh16']
#  ['gd64']
#  ['te51']
#  ['o522']
#  ['d643']
#  ['n409']
#  ['sx91']
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  ['d643']
#  [nan]
#  ['tb69']
#  ['ki95']
#  [nan]
#  ['d643']
#  ['re44']
#  [nan]
#  [nan]
#  ['n409']
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  [nan]
#  ['re44']
#  ['z355']
#  ['db63']
#  [nan]
#  [nan]
#  ['hh26']
#  ['z355']
#  [nan]
#  ['re44']
#  ['mh30']
#  ['mm58']
#  ['s0ag']
#  [nan]
#  ['mm58']
#  ['hb71']
#  ['dh58']
#  [nan]
#  ['s0ag']
#  ['e687']
#  [nan]
#  ['mm58']
#  ['d643']
#  [nan]
#  [nan]
#  ['p09z']
#  ['c0c8']
#  ['gb88']
#  ['re44']
#  ['sm37']
#  ['bg23']
#  ['mm58']
#  ['gd64']
#  ['kc56']
#  ['z355']
#  ['hb71']
#  [nan]
# ...

# %%
print(T_ind.count('a0e2'))
# Out:
# 7
